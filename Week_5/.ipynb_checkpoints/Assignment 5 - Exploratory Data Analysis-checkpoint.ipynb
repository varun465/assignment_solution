# %% [markdown]
# *Difficulty level -  Easy*
#
# Dataset: You are provided with a dataset named "sales_data.csv," which contains information about sales transactions. The dataset includes columns such as "Date," "Product," "Quantity," "Price," and "Customer."
#
# Include comments and explanations in your code to make it clear and understandable.
# Provide appropriate titles and labels for your plots
#
# Tasks:
# 1 Load the dataset using Pandas and display the first few rows to understand its structure.
# 2 Perform data cleaning:
#     •	Check for missing values and decide on a strategy to handle them.
#     •	Identify and remove any duplicate rows.
# 3 Compute and display the following summary statistics:
#     •	Mean, median, and standard deviation of the "Quantity" and "Price" columns.
#     •	Total sales revenue (computed as the sum of Quantity * Price).
# 4 Visualize the data:
#     •	Create a histogram of the "Quantity" column to understand the distribution of sales quantities.
#     •	Generate a scatter plot of "Price" vs. "Quantity" to explore any potential relationships.
# 5 Perform categorical analysis:
#     •	Group the data by "Product" and compute the total quantity sold and average price for each product.
#     •	Visualize the product-wise sales using a bar chart.
# 6 Identify outliers:
#     •	Use the z-score method to detect potential outliers in the "Price" column.
#     •	Visualize the outliers using a box plot.
# 7 Additional Analysis:
#     •	Calculate the weekly sales by aggregating the data based on the "Date" column.
#     •	Visualize the weekly sales trend over time using a line plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Task 1: Load the dataset
data = pd.read_csv(r'C:/Users/SV488YV/OneDrive - EY/Desktop/Learning/Python/Week_5/sales_data.csv')
data
# Out:
#        Order ID                     Product  Quantity   Price  \
# 0        176558        USB-C Charging Cable         2   11.95
# 1        176559  Bose SoundSport Headphones         1   99.99
# 2        176560                Google Phone         1  600.00
# 3        176560            Wired Headphones         1   11.99
# 4        176561            Wired Headphones         1   11.99
# ...         ...                         ...       ...     ...
# 18284    194090                Google Phone         1  600.00
# 18285    194091       AA Batteries (4-pack)         1    3.84
# 18286    194092      AAA Batteries (4-pack)         2    2.99
# 18287    194093       AA Batteries (4-pack)         1    3.84
# 18288    194094    Lightning Charging Cable         1   14.95
#
#              Order Date                                Customer
# 0        04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1      04-07-2019 22:30       682 Chestnut St, Boston, MA 02215
# 2      04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 3      04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 4        04/30/19 09:27       333 8th St, Los Angeles, CA 90001
# ...                 ...                                     ...
# 18284  04-08-2019 17:11   177 Jackson St, Los Angeles, CA 90001
# 18285    04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18286    04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18287    04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18288    04/18/19 11:08          354 North St, Boston, MA 02215
#
# [18289 rows x 6 columns]

# %%
#Task 2 Perform data cleaning: • Check for missing values and decide on a strategy to handle them. • Identify and remove any duplicate rows.

# %%
data.head()
# Out:
#    Order ID                     Product  Quantity   Price        Order Date  \
# 0    176558        USB-C Charging Cable         2   11.95    04/19/19 08:46
# 1    176559  Bose SoundSport Headphones         1   99.99  04-07-2019 22:30
# 2    176560                Google Phone         1  600.00  04-12-2019 14:38
# 3    176560            Wired Headphones         1   11.99  04-12-2019 14:38
# 4    176561            Wired Headphones         1   11.99    04/30/19 09:27
#
#                                Customer
# 0          917 1st St, Dallas, TX 75001
# 1     682 Chestnut St, Boston, MA 02215
# 2  669 Spruce St, Los Angeles, CA 90001
# 3  669 Spruce St, Los Angeles, CA 90001
# 4     333 8th St, Los Angeles, CA 90001

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18289 entries, 0 to 18288
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order ID    18289 non-null  int64
#  1   Product     18289 non-null  object
#  2   Quantity    18289 non-null  int64
#  3   Price       18289 non-null  float64
#  4   Order Date  18289 non-null  object
#  5   Customer    18289 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 857.4+ KB

# %%
data.nunique()
# Out:
# Order ID      17537
# Product          19
# Quantity          7
# Price            17
# Order Date    13583
# Customer      17119
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#        Order ID                     Product  Quantity   Price  \
# 30       176585  Bose SoundSport Headphones         1   99.99
# 1296     177795    Apple Airpods Headphones         1  150.00
# 1675     178158        USB-C Charging Cable         1   11.95
# 3786     180207    Apple Airpods Headphones         1  150.00
# 4176     180576    Lightning Charging Cable         1   14.95
# 4355     180746      AAA Batteries (4-pack)         1    2.99
# 4429     180817    Lightning Charging Cable         1   14.95
# 4711     181084               Flatscreen TV         1  300.00
# 4882     181246            Wired Headphones         1   11.99
# 5746     182077      AAA Batteries (4-pack)         1    2.99
# 6213     182523    Lightning Charging Cable         1   14.95
# 6615     182904    Lightning Charging Cable         1   14.95
# 7338     183587      AAA Batteries (4-pack)         1    2.99
# 8503     184717        USB-C Charging Cable         1   11.95
# 9004     185193    Lightning Charging Cable         1   14.95
# 9850     186008  Bose SoundSport Headphones         1   99.99
# 11277    187379        USB-C Charging Cable         1   11.95
# 12802    188827        USB-C Charging Cable         1   11.95
# 14125    190099       AA Batteries (4-pack)         1    3.84
# 14598    190553    Lightning Charging Cable         1   14.95
# 17076    192939      34in Ultrawide Monitor         1  379.99
# 18100    193916                20in Monitor         1  109.99
#
#              Order Date                                 Customer
# 30     04-07-2019 11:31        823 Highland St, Boston, MA 02215
# 1296     04/27/19 19:45           740 14th St, Seattle, WA 98101
# 1675     04/28/19 21:13   197 Center St, San Francisco, CA 94016
# 3786     04/13/19 01:46        196 7th St, Los Angeles, CA 90001
# 4176     04/18/19 17:23            431 Park St, Dallas, TX 75001
# 4355     04/30/19 12:05     398 West St, New York City, NY 10001
# 4429     04/13/19 18:33       563 13th St, Los Angeles, CA 90001
# 4711   04-07-2019 21:36            1 Walnut St, Boston, MA 02215
# 4882   04-09-2019 13:58  342 Hickory St, San Francisco, CA 94016
# 5746     04/13/19 22:08      730 4th St, New York City, NY 10001
# 6213     04/24/19 21:16           990 River St, Boston, MA 02215
# 6615   04-09-2019 22:15         410 Wilson St, Atlanta, GA 30301
# 7338     04/15/19 00:21     384 Sunset St, Los Angeles, CA 90001
# 8503   04-04-2019 10:17         439 Forest St, Atlanta, GA 30301
# 9004     04/16/19 21:38     714 13th St, San Francisco, CA 94016
# 9850     04/17/19 19:36     432 Park St, New York City, NY 10001
# 11277  04-10-2019 19:06       504 10th St, Los Angeles, CA 90001
# 12802    04/17/19 18:17   900 Spruce St, New York City, NY 10001
# 14125    04/18/19 08:07     845 Sunset St, Los Angeles, CA 90001
# 14598  04-10-2019 17:38  548 Madison St, New York City, NY 10001
# 17076    04/29/19 21:07          519 Adams St, Seattle, WA 98101
# 18100    04/18/19 12:59          653 Cherry St, Dallas, TX 75001

# %%
data.drop_duplicates(inplace = True)

# %%
# Task3 Compute and display the following summary statistics: • Mean, median, and standard deviation of the "Quantity" and "Price" columns.
#• Total sales revenue (computed as the sum of Quantity * Price)

# %%
data[['Quantity','Price']].describe()
# Out:
#            Quantity         Price
# count  18267.000000  18267.000000
# mean       1.124760    184.573645
# std        0.436651    331.069060
# min        1.000000      2.990000
# 25%        1.000000     11.950000
# 50%        1.000000     14.950000
# 75%        1.000000    150.000000
# max        7.000000   1700.000000

# %%
data['Revenue'] = data['Quantity']*data['Price']
data
# Out:
#        Order ID                     Product  Quantity   Price  \
# 0        176558        USB-C Charging Cable         2   11.95
# 1        176559  Bose SoundSport Headphones         1   99.99
# 2        176560                Google Phone         1  600.00
# 3        176560            Wired Headphones         1   11.99
# 4        176561            Wired Headphones         1   11.99
# ...         ...                         ...       ...     ...
# 18284    194090                Google Phone         1  600.00
# 18285    194091       AA Batteries (4-pack)         1    3.84
# 18286    194092      AAA Batteries (4-pack)         2    2.99
# 18287    194093       AA Batteries (4-pack)         1    3.84
# 18288    194094    Lightning Charging Cable         1   14.95
#
#              Order Date                                Customer  Revenue
# 0        04/19/19 08:46            917 1st St, Dallas, TX 75001    23.90
# 1      04-07-2019 22:30       682 Chestnut St, Boston, MA 02215    99.99
# 2      04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001   600.00
# 3      04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001    11.99
# 4        04/30/19 09:27       333 8th St, Los Angeles, CA 90001    11.99
# ...                 ...                                     ...      ...
# 18284  04-08-2019 17:11   177 Jackson St, Los Angeles, CA 90001   600.00
# 18285    04/15/19 16:02         311 Forest St, Austin, TX 73301     3.84
# 18286    04/28/19 14:36  347 Sunset St, San Francisco, CA 94016     5.98
# 18287    04/14/19 15:09         835 Lake St, Portland, OR 97035     3.84
# 18288    04/18/19 11:08          354 North St, Boston, MA 02215    14.95
#
# [18267 rows x 7 columns]

# %%
data['Revenue'].sum()
# Out:
# 3394606.849999999

# %%
# Task 4 Visualize the data: • Create a histogram of the "Quantity" column to understand the distribution of sales quantities.• Generate a scatter plot of "Price" vs. "Quantity" to explore any potential relationships.

# %%
fig,ax = plt.subplots(1,2, figsize = (15,5))
ax[0].hist(data['Quantity'])
ax[0].set_xlabel('Quantity')

ax[1].scatter(data['Price'],data['Quantity'])
ax[1].set_xlabel('Price')
ax[1].set_ylabel('Quantity')

plt.plot()
# Out:
# []

# %%
# Task 5 Perform categorical analysis: • Group the data by "Product" and compute the total quantity sold and average price
#for each product. • Visualize the product-wise sales using a bar chart.

# %%
df1 = data.groupby('Product')[['Quantity','Price']].agg(['sum','mean'])
df1
# Out:
#                            Quantity                Price
#                                 sum      mean        sum     mean
# Product
# 20in Monitor                    394  1.012853   42786.11   109.99
# 27in 4K Gaming Monitor          565  1.003552  219564.37   389.99
# 27in FHD Monitor                737  1.004087  110092.66   149.99
# 34in Ultrawide Monitor          652  1.004622  246613.51   379.99
# AA Batteries (4-pack)          2821  1.368089    7918.08     3.84
# AAA Batteries (4-pack)         2933  1.476838    5938.14     2.99
# Apple Airpods Headphones       1523  1.006609  226950.00   150.00
# Bose SoundSport Headphones     1286  1.006260  127787.22    99.99
# Flatscreen TV                   458  1.002188  137100.00   300.00
# Google Phone                    581  1.000000  348600.00   600.00
# LG Dryer                         77  1.000000   46200.00   600.00
# LG Washing Machine               61  1.000000   36600.00   600.00
# Lightning Charging Cable       2365  1.077449   32815.25    14.95
# Macbook Pro Laptop              455  1.004415  770100.00  1700.00
# ThinkPad Laptop                 392  1.000000  391996.08   999.99
# USB-C Charging Cable           2266  1.092048   24796.25    11.95
# Vareebadd Phone                 220  1.000000   88000.00   400.00
# Wired Headphones               2065  1.093171   22649.11    11.99
# iPhone                          695  1.002886  485100.00   700.00

# %%
product_sales = df1['Quantity']['sum']
product_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
# Task6 Identify outliers: • Use the z-score method to detect potential outliers in the "Price" column.
#• Visualize the outliers using a box plot.

# %%
data['z_scores'] = (data['Price'] - data['Price'].mean())/ data['Price'].std()
data
# Out:
#        Order ID                     Product  Quantity   Price  \
# 0        176558        USB-C Charging Cable         2   11.95
# 1        176559  Bose SoundSport Headphones         1   99.99
# 2        176560                Google Phone         1  600.00
# 3        176560            Wired Headphones         1   11.99
# 4        176561            Wired Headphones         1   11.99
# ...         ...                         ...       ...     ...
# 18284    194090                Google Phone         1  600.00
# 18285    194091       AA Batteries (4-pack)         1    3.84
# 18286    194092      AAA Batteries (4-pack)         2    2.99
# 18287    194093       AA Batteries (4-pack)         1    3.84
# 18288    194094    Lightning Charging Cable         1   14.95
#
#              Order Date                                Customer  Revenue  \
# 0        04/19/19 08:46            917 1st St, Dallas, TX 75001    23.90
# 1      04-07-2019 22:30       682 Chestnut St, Boston, MA 02215    99.99
# 2      04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001   600.00
# 3      04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001    11.99
# 4        04/30/19 09:27       333 8th St, Los Angeles, CA 90001    11.99
# ...                 ...                                     ...      ...
# 18284  04-08-2019 17:11   177 Jackson St, Los Angeles, CA 90001   600.00
# 18285    04/15/19 16:02         311 Forest St, Austin, TX 73301     3.84
# 18286    04/28/19 14:36  347 Sunset St, San Francisco, CA 94016     5.98
# 18287    04/14/19 15:09         835 Lake St, Portland, OR 97035     3.84
# 18288    04/18/19 11:08          354 North St, Boston, MA 02215    14.95
#
#        z_scores
# 0     -0.521413
# 1     -0.255486
# 2      1.254803
# 3     -0.521292
# 4     -0.521292
# ...         ...
# 18284  1.254803
# 18285 -0.545909
# 18286 -0.548477
# 18287 -0.545909
# 18288 -0.512351
#
# [18267 rows x 8 columns]

# %%
data[data['z_scores'] > 3]
# Out:
#        Order ID             Product  Quantity   Price        Order Date  \
# 8        176565  Macbook Pro Laptop         1  1700.0    04/24/19 10:38
# 85       176639  Macbook Pro Laptop         1  1700.0    04/28/19 16:14
# 89       176643  Macbook Pro Laptop         1  1700.0    04/27/19 21:32
# 92       176646  Macbook Pro Laptop         1  1700.0    04/22/19 07:14
# 135      176687  Macbook Pro Laptop         1  1700.0    04/30/19 10:26
# ...         ...                 ...       ...     ...               ...
# 18017    193839  Macbook Pro Laptop         1  1700.0  04-05-2019 14:46
# 18067    193885  Macbook Pro Laptop         1  1700.0    04/16/19 08:47
# 18079    193897  Macbook Pro Laptop         1  1700.0    04/16/19 19:19
# 18160    193972  Macbook Pro Laptop         1  1700.0  04-11-2019 16:23
# 18209    194019  Macbook Pro Laptop         1  1700.0    04/20/19 11:44
#
#                                      Customer  Revenue  z_scores
# 8      915 Willow St, San Francisco, CA 94016   1700.0  4.577372
# 85      853 Cedar St, San Francisco, CA 94016   1700.0  4.577372
# 89             373 Adams St, Boston, MA 02215   1700.0  4.577372
# 92           657 Adams St, Portland, OR 97035   1700.0  4.577372
# 135      121 Wilson St, Los Angeles, CA 90001   1700.0  4.577372
# ...                                       ...      ...       ...
# 18017  984 Sunset St, San Francisco, CA 94016   1700.0  4.577372
# 18067            837 6th St, Austin, TX 73301   1700.0  4.577372
# 18079  489 Chestnut St, Los Angeles, CA 90001   1700.0  4.577372
# 18160     334 5th St, San Francisco, CA 94016   1700.0  4.577372
# 18209         418 Maple St, Seattle, WA 98101   1700.0  4.577372
#
# [453 rows x 8 columns]

# %%
data['z_scores'] < -3
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18284    False
# 18285    False
# 18286    False
# 18287    False
# 18288    False
# Name: z_scores, Length: 18267, dtype: bool

# %%
import seaborn as sns
sns.boxplot(x=data['Price'] )
# Out:
# <Axes: xlabel='Price'>

# %%
#Task7 Additional Analysis: • Calculate the weekly sales by aggregating the data based on the "Date" column. 
#• Visualize the weekly sales trend over time using a line plot.

# %% [markdown]
# *Difficulty level - Medium*
# Analyse the given dataset and come up with an analysis using different metrics and plots to answer the questions below:
#
# After each question intsert a code to justify your answer and also write down the answer in the text box itself.

# %%
smSales = pd.read_csv(r'C:/Users/SV488YV/OneDrive - EY/Desktop/Learning/Python/Week_5/supermarket_sales.csv')
smSales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %% [markdown]
# Q1: What does the customer rating look like and is it skewed?
#
# Answer -

# %%
# <Inset Code Here>
smSales[['Rating']]
fig, ax = plt.subplots(figsize = (10,5))
ax.hist(smSales[['Rating']] ,edgecolor = 'white')
plt.plot();
smSales[['Rating']].skew()
# Out:
# Rating    0.00901
# dtype: float64

# %% [markdown]
# Q2: Is there any difference in aggregate sales across branches?
#
# A-

# %%
smSales.groupby('Branch')[['Total']].agg(['sum'])
# Out:
#               Total
#                 sum
# Branch
# A       106200.3705
# B       106197.6720
# C       110568.7065

# %%
smSales.groupby('Branch')['Total'].sum().plot.bar( fontsize=12)
# Out:
# <Axes: xlabel='Branch'>

# %% [markdown]
# Question 3: Which is the most pouplar payment method used by customers?
#
# A-

# %%
sns.countplot( x = 'Payment', data = smSales, color = 'blue',
              order = smSales['Payment'].value_counts().index);

# %% [markdown]
# Q4: Does gross income affect the ratings that the customers provide?
#
# A-

# %%
fig,ax = plt.subplots( figsize = (15,5))
ax.scatter(smSales['gross income'],smSales['Rating'])

# %% [markdown]
# Q5: Which branch is the most profitable?
#
# A-

# %%
smSales.groupby('Branch')['gross income'].sum().plot.bar( fontsize=12)
# Out:
# <Axes: xlabel='Branch'>

# %% [markdown]
# Q6: Is there any time trend in gross income?
#
# A-

# %%
fig,ax = plt.subplots(figsize = (15,5))
ax.scatter(smSales['Date'], smSales['gross income'])
ax.tick_params(axis = 'x',labelrotation=90)
plt.plot();

# %% [markdown]
# Q7: Which product line generates most income?
#
# A-

# %%
smSales1 = smSales[['Product line','Unit price','Quantity']]
smSales1['t_sales'] = smSales['Unit price']*smSales['Quantity']
smSales1
# Out:
# C:\Users\SV488YV\AppData\Local\Temp\ipykernel_57324\1196760347.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smSales1['t_sales'] = smSales['Unit price']*smSales['Quantity']
#                Product line  Unit price  Quantity  t_sales
# 0         Health and beauty       74.69         7   522.83
# 1    Electronic accessories       15.28         5    76.40
# 2        Home and lifestyle       46.33         7   324.31
# 3         Health and beauty       58.22         8   465.76
# 4         Sports and travel       86.31         7   604.17
# ..                      ...         ...       ...      ...
# 995       Health and beauty       40.35         1    40.35
# 996      Home and lifestyle       97.38        10   973.80
# 997      Food and beverages       31.84         1    31.84
# 998      Home and lifestyle       65.82         1    65.82
# 999     Fashion accessories       88.34         7   618.38
#
# [1000 rows x 4 columns]

# %%
smSales1.groupby('Product line')['t_sales'].sum()
# Out:
# Product line
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Food and beverages        53471.28
# Health and beauty         46851.18
# Home and lifestyle        51297.06
# Sports and travel         52497.93
# Name: t_sales, dtype: float64

# %% [markdown]
# Q8: Show the correlation between all variable.

# %%
sns.heatmap(smSales.drop(['gross margin percentage'],axis=1).corr(), annot = True, vmin = -1, vmax = 1)
# Out:
# C:\Users\SV488YV\AppData\Local\Temp\ipykernel_57324\2171475114.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(smSales.drop(['gross margin percentage'],axis=1).corr(), annot = True, vmin = -1, vmax = 1)
# <Axes: >
